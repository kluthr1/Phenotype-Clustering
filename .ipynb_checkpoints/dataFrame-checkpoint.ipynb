# %%
from parseData import *
import pandas as pd
import pickle

# %%
print getType('C1968550')
# Out:
# Disease or Syndrome

# %%
df = pd.read_csv('./sample.txt', sep="\t")
dfSample = pd.read_csv('./Second_250_Sample.txt.txt', sep="\t")
dfSample['Name Relations'] = dfSample.apply(lambda x: relatedByName(x['Disease1'], x['Disease2']), axis = 1)
dfSample['Paper Relations'] = dfSample.apply(lambda x: relatedByPapers(x['PubMed1'], x['PubMed2'], x['Common_PubMed_IDs']), axis = 1)

dfSample
# Out:
#      Unnamed: 0  Unnamed: 0.1      CUI1      CUI2  \
# 0             0             0  C3889305  C3891922
# 1             1             1  C0015503  C0015526
# 2             2             2  C0699743  C1846672
# 3             3             3  C0009952  C4016378
# 4             4             4  C1876175  C3469522
# 5             5             5  C0265253  C0265279
# 6             6             6  C0085390  C1510426
# 7             7             7  C0018553  C1868081
# 8             8             8  C0403553  C1857662
# 9             9             9  C0006142  C4015968
# 10           10            10  C1867983  C2673195
# 11           11            11  C0268276  C4310893
# 12           12            12  C1838100  C3275844
# 13           13            13  C0013720  C1858084
# 14           14            14  C1865643  C4272382
# 15           15            15  C0010273  C0220658
# 16           16            16  C0033806  C0334041
# 17           17            17  C0338503  C0857439
# ...

# %%
dfSample['Context Type'] = dfSample.apply(lambda x: typeSame(x['CUI1'], x['CUI2']), axis = 1)
# Out:
# C3889305
# C0015503
# C0699743
# C0009952
# C1876175
# C0265253
# C0085390
# C0018553
# C0403553
# C0006142
# C1867983
# C0268276
# C1838100
# C0013720
# C1865643
# C0010273
# C0033806
# C0338503
# C0406704
# C0035372
# C0021359
# C0020538
# C0022579
# C0238111
# C0017668
# C0267663
# C0234166
# C0342384
# C0017661
# C1527405
# C0265253
# C4015858
# C1850386
# C1264039
# C0079294
# C0023264
# C0007102
# C0009691
# C0020479
# C0011860
# C1706595
# C0003850
# C0270912
# C0342870
# C0023931
# C0032463
# C0007193
# C0024145
# C0011265
# C0005283
# C0005283
# C0175694
# C0346429
# C0007193
# C0010273
# C0265281
# C0033804
# C0041207
# C0349653
# C0002768
# C0271980
# C0162674
# C0238462
# C0013336
# C0270612
# C1283400
# C1852510
# C0339526
# C0342579
# C0750384
# C2939465
# C1860406
# C0265216
# C0011854
# C1721007
# C0079301
# C0339510
# C1275081
# C0039743
# C0752166
# C0085298
# C0029464
# C0340978
# C0029456
# C0079661
# C0085584
# C0007193
# C0346429
# C0265202
# C0270862
# ...

# %%
#dfSample.to_csv('./sampleTwoRelation.txt', sep = "\t")

# %%
dfSample['Concept Relations Type'] = dfSample.apply(lambda x: relationTypeAndConfidence(x['CUI1'], x['CUI2']), axis = 1)
# Out:
# C3889305    C3891922
# C0015503    C0015526
# C0699743    C1846672
# C0009952    C4016378
# C1876175    C3469522
# C0265253    C0265279
# C0085390    C1510426
# C0018553    C1868081
# C0403553    C1857662
# C0006142    C4015968
# C1867983    C2673195
# C0268276    C4310893
# C1838100    C3275844
# C0013720    C1858084
# C1865643    C4272382
# C0010273    C0220658
# C0033806    C0334041
# C0338503    C0857439
# C0406704    C1858562
# C0035372    C1968550
# C0021359    C0342384
# C0020538    C1851511
# C0022579    C0265334
# C0238111    C1096063
# C0017668    C3151568
# C0267663    C2678346
# C0234166    C4084968
# C0342384    C4016133
# C0017661    C0017662
# C1527405    C3889305
# C0265253    C0542428
# C4015858    C4017425
# C1850386    C4016946
# C1264039    C1264041
# C0079294    C0268374
# C0023264    C0268237
# C0007102    C1837315
# C0009691    C0018522
# C0020479    C4017423
# C0011860    C0158981
# C1706595    C2931923
# C0003850    C0270612
# C0270912    C0270922
# ...

# %%
dfSample
# Out:
#      Unnamed: 0  Original Row      CUI1      CUI2  \
# 0             0          8853  C3889305  C3891922
# 1             1          2085  C0015503  C0015526
# 2             2          7348  C0699743  C1846672
# 3             3          8976  C0009952  C4016378
# 4             4          3529  C1876175  C3469522
# 5             5          5171  C0265253  C0265279
# 6             6          5737  C0085390  C1510426
# 7             7          3408  C0018553  C1868081
# 8             8          8002  C0403553  C1857662
# 9             9         12384  C0006142  C4015968
# 10           10         11284  C1867983  C2673195
# 11           11          5795  C0268276  C4310893
# 12           12          5888  C1838100  C3275844
# 13           13          9922  C0013720  C1858084
# 14           14          6019  C1865643  C4272382
# 15           15          1077  C0010273  C0220658
# 16           16          3476  C0033806  C0334041
# 17           17          2032  C0338503  C0857439
# ...

# %%
dfSample.to_csv('./finalChecks.txt', sep = "\t")

# %% [markdown]
# dfSample

# %%
dfSample
# Out:
#      Unnamed: 0  Unnamed: 0.1      CUI1      CUI2  \
# 0             0             0  C3889305  C3891922
# 1             1             1  C0015503  C0015526
# 2             2             2  C0699743  C1846672
# 3             3             3  C0009952  C4016378
# 4             4             4  C1876175  C3469522
# 5             5             5  C0265253  C0265279
# 6             6             6  C0085390  C1510426
# 7             7             7  C0018553  C1868081
# 8             8             8  C0403553  C1857662
# 9             9             9  C0006142  C4015968
# 10           10            10  C1867983  C2673195
# 11           11            11  C0268276  C4310893
# 12           12            12  C1838100  C3275844
# 13           13            13  C0013720  C1858084
# 14           14            14  C1865643  C4272382
# 15           15            15  C0010273  C0220658
# 16           16            16  C0033806  C0334041
# 17           17            17  C0338503  C0857439
# ...

# %%
dfSample['Num Available'] = dfSample.apply(lambda x: numAtomRelations(x['CUI1'], x['CUI2']), axis = 1)
# Out:
# C3889305
# C0015503
# C0699743
# C0009952
# C1876175
# C0265253
# C0085390
# C0018553
# C0403553
# C0006142
# C1867983
# C0268276
# C1838100
# C0013720
# C1865643
# C0010273
# C0033806
# C0338503
# C0406704
# C0035372
# C0021359
# C0020538
# C0022579
# C0238111
# C0017668
# C0267663
# C0234166
# C0342384
# C0017661
# C1527405
# C0265253
# C4015858
# C1850386
# C1264039
# C0079294
# C0023264
# C0007102
# C0009691
# C0020479
# C0011860
# C1706595
# C0003850
# C0270912
# C0342870
# C0023931
# C0032463
# C0007193
# C0024145
# C0011265
# C0005283
# C0005283
# C0175694
# C0346429
# C0007193
# C0010273
# C0265281
# C0033804
# C0041207
# C0349653
# C0002768
# C0271980
# C0162674
# C0238462
# C0013336
# C0270612
# C1283400
# C1852510
# C0339526
# C0342579
# C0750384
# C2939465
# C1860406
# C0265216
# C0011854
# C1721007
# C0079301
# C0339510
# C1275081
# C0039743
# C0752166
# C0085298
# C0029464
# C0340978
# C0029456
# C0079661
# C0085584
# C0007193
# C0346429
# C0265202
# C0270862
# ...

# %%
#Simplify PANDAS
dfSample['Concept Relation'] = dfSample.apply(lambda x: simpleRelation(x['Concept Relations Type']), axis = 1)
dfSample['ID Relation'] = dfSample.apply(lambda x: simpleRelation(x['Pct Common Relations']), axis = 1)
# Out:
# ['N/A', '10']
# 10
# ['N/A', '10']
# 10
# [u'RO', 6]
# 6
# ['N/A', '10']
# 10
# ['N/A', '10']
# 10
# [u'RO', 6]
# 6
# [u'RO', 6]
# 6
# ['N/A', '10']
# 10
# ['N/A', '10']
# 10
# ['N/A', '10']
# 10
# ['N/A', '10']
# 10
# ['N/A', '10']
# 10
# ['N/A', '10']
# 10
# ['N/A', '10']
# 10
# ['N/A', '10']
# 10
# [u'RO', 6]
# 6
# [u'RO', 6]
# 6
# [u'RN2', 4]
# 4
# [u'RO', 6]
# 6
# [u'RO', 6]
# 6
# [u'RO', 6]
# 6
# ['N/A', '10']
# 10
# [u'RO', 6]
# 6
# ['N/A', '10']
# 10
# [u'RO', 6]
# 6
# ['N/A', '10']
# 10
# [u'RO', 6]
# 6
# ['N/A', '10']
# 10
# [u'RO', 6]
# 6
# ['N/A', '10']
# 10
# [u'RO', 6]
# 6
# ['N/A', '10']
# 10
# ['N/A', '10']
# 10
# ['N/A', '10']
# 10
# [u'RO', 6]
# 6
# [u'RO', 6]
# 6
# ['N/A', '10']
# 10
# [u'RO', 6]
# 6
# ['N/A', '10']
# 10
# [u'RB2', 5]
# 5
# [u'RO', 6]
# 6
# [u'RO', 6]
# 6
# ['N/A', '10']
# 10
# [u'RO', 6]
# 6
# [u'RO', 6]
# 6
# [u'RO', 6]
# 6
# [u'RO', 6]
# 6
# [u'RO', 6]
# 6
# ['N/A', '10']
# 10
# ['N/A', '10']
# 10
# ['N/A', '10']
# 10
# ['N/A', '10']
# 10
# ...

# %%
dfSample['Num Relations'] = dfSample.apply(lambda x: getValueA(x['Num Available']), axis = 1)
dfSample['Num Atoms'] = dfSample.apply(lambda x: getValueB(x['Num Available']), axis = 1)

# %%
dfSample
# Out:
#      Unnamed: 0      CUI1      CUI2  \
# 0             0  C3889305  C3891922
# 1             1  C0015503  C0015526
# 2             2  C0699743  C1846672
# 3             3  C0009952  C4016378
# 4             4  C1876175  C3469522
# 5             5  C0265253  C0265279
# 6             6  C0085390  C1510426
# 7             7  C0018553  C1868081
# 8             8  C0403553  C1857662
# 9             9  C0006142  C4015968
# 10           10  C1867983  C2673195
# 11           11  C0268276  C4310893
# 12           12  C1838100  C3275844
# 13           13  C0013720  C1858084
# 14           14  C1865643  C4272382
# 15           15  C0010273  C0220658
# 16           16  C0033806  C0334041
# 17           17  C0338503  C0857439
# 18           18  C0406704  C1858562
# 19           19  C0035372  C1968550
# 20           20  C0021359  C0342384
# 21           21  C0020538  C1851511
# 22           22  C0022579  C0265334
# 23           23  C0238111  C1096063
# 24           24  C0017668  C3151568
# ...

# %%
df_shortened['Concept Relations Type'] = df_shortened.apply(lambda x: relationTypeAndConfidence(x['CUI1'], x['CUI2'])[0], axis = 1)
df_shortened['Concept Relations Weight'] = df_shortened.apply(lambda x: relationTypeAndConfidence(x['CUI1'], x['CUI2'])[1], axis = 1)
df_shortened
# Out:
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        CUI1      CUI2                       Disease1  \
# 0  C4017553  C4017554             CHE*390V PHENOTYPE
# 1  C4017550  C4017551             CHE*243M PHENOTYPE
# 2  C4017544  C4017545              CHE*70G PHENOTYPE
# ...

# %%
getAtomConfidence(df.loc()[4]['CUI1'], df.loc()[4]['CUI2'])
# Out:
# [54.0, 4]

# %%
df_shortened['Pct Common Relations'] = df_shortened.apply(lambda x: getAtomConfidence(x['CUI1'], x['CUI2']), axis = 1)
df_shortened
# Out:
# run
# run1
# run2
# run
# run1
# run2
# run
# run1
# run2
# run
# run1
# run
# run1
# run
# run1
# run
# run1
# run
# run1
# run
# run
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#        CUI1      CUI2                       Disease1  \
# 0  C4017553  C4017554             CHE*390V PHENOTYPE
# 1  C4017550  C4017551             CHE*243M PHENOTYPE
# 2  C4017544  C4017545              CHE*70G PHENOTYPE
# 3  C0018798  C3278404       Congenital Heart Defects
# 4  C0011847  C0011860                       Diabetes
# 5  C0000768  C3553943         Congenital Abnormality
# 6  C0025362  C3151356             Mental Retardation
# ...

# %%
dfAdding

# %%
df['ID Relations Weight'] = df.apply(lambda x: getAtomConfidence(x['CUI1'], x['CUI2'])[1], axis = 1)
print "BOB"
